# %% [markdown]
# <a href="https://colab.research.google.com/github/shrikantkhule100-ux/My-AI-Journey/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
stored_password = "12345"
entered_password= "1234"

if entered_password==stored_password:
  print("Acess granted")
  print("WELCOME TO AI 2026")

else:
  print("acess denied")
  print("please check password and enter again")
# Out:
# acess denied
# please check password and enter again
