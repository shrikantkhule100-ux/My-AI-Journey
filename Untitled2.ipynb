# %% [markdown]
# <a href="https://colab.research.google.com/github/shrikantkhule100-ux/My-AI-Journey/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cart=["milk","apple","bread","choclate","burger"]
print(cart)
for item in cart:
  if item== "choclate":
    print("found it! Applying 50% disscount on choclate!")
  else:
    print("scanning the item "   + item)
# Out:
# ['milk', 'apple', 'bread', 'choclate', 'burger']
# scanning the item milk
# scanning the item apple
# scanning the item bread
# found it! Applying 50% disscount on choclate!
# scanning the item burger
