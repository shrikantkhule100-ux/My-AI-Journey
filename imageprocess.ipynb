# %% [markdown]
# <a href="https://colab.research.google.com/github/shrikantkhule100-ux/My-AI-Journey/blob/main/imageprocess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
horse_img = plt.imread("HORSE.jpg")
plt.imshow(horse_img)
plt.axis("off")
type(horse_img)
#horizontal_flip = np.fliplr(horse_img)
red=horse_img[:, :, 0]
#print (red)



#plt.imshow(red, cmap="gray")
plt.title('red')
plt.show()
vertical_flip = np.flipud(horse_img)
plt.show()
print(horse_img.shape)
print(horse_img.size)
plt.hist(red.ravel(), bins=256)
plt.show()
# Out:
# (980, 1470, 3)
# 4321800
